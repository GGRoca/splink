# %%
import pandas as pd
import pathlib
import duckdb
from IPython.display import display, HTML
import unidecode
import textwrap

# --- Parâmetros de Entrada ---
PASTA_PROCESSED = pathlib.Path("dados_catalogo") / "processed"
ARQUIVO_DE_ENTRADA = PASTA_PROCESSED / 'dados_consolidados_filtrados.parquet'
#ARQUIVO_DE_SAIDA = PASTA_PROCESSED / 'tabela_dimensao_splink.parquet'
ARQUIVO_DE_SAIDA_LIMPO = PASTA_PROCESSED / 'tabela_dimensao_limpa_para_splink.parquet'

# --- Regras de Negócio Já Definidas ---
# Semanas a serem EXCLUÍDAS da análise de metadados, com base na nossa investigação.
SEMANAS_A_EXCLUIR = ['2024-10-25', '2024-11-21']

print("--- Etapa 3: Análise Exploratória e Preparação da Tabela Dimensão ---")
print("Bloco 1: Configurações carregadas.")
# Out:
# --- Etapa 3: Análise Exploratória e Preparação da Tabela Dimensão ---
# Bloco 1: Configurações carregadas.

# %%
print("\n" + "="*80)
print(" ANÁLISE EXPLORATÓRIA 1: COMPLETUDE DAS COLUNAS")
print("="*80)
print("Analisando o percentual de preenchimento (não-nulos) de cada coluna...")

try:
    con = duckdb.connect(database=':memory:')
    df_schema = con.execute(f"DESCRIBE SELECT * FROM read_parquet('{str(ARQUIVO_DE_ENTRADA)}');").fetch_df()
    colunas = df_schema['column_name'].tolist()
    
    metricas_completude = []
    for col in colunas:
        query = f"SELECT 100.0 * COUNT(\"{col}\") / COUNT(*) FROM read_parquet('{str(ARQUIVO_DE_ENTRADA)}');"
        pct_preenchimento = con.execute(query).fetchone()[0]
        metricas_completude.append({"Coluna": col, "Preenchimento (%)": pct_preenchimento})
        
    df_completude = pd.DataFrame(metricas_completude).sort_values(by="Preenchimento (%)", ascending=False)

    display(HTML("<h4>Relatório de Completude de Colunas</h4>"))
    display(df_completude.style.format({'Preenchimento (%)': '{:.2f}%'})
            .bar(subset=['Preenchimento (%)'], color='#5DADE2', vmin=0, vmax=100))
    
    con.close()
except Exception as e:
    print(f"ERRO durante a análise de completude: {e}")
    if 'con' in locals(): con.close()
# Out:
# ================================================================================
#  ANÁLISE EXPLORATÓRIA 1: COMPLETUDE DAS COLUNAS
# ================================================================================
# Analisando o percentual de preenchimento (não-nulos) de cada coluna...
# <h4>Relatório de Completude de Colunas</h4>
# <style type="text/css">
# #T_0d79b_row0_col1, #T_0d79b_row1_col1, #T_0d79b_row2_col1, #T_0d79b_row3_col1, #T_0d79b_row4_col1, #T_0d79b_row5_col1, #T_0d79b_row6_col1, #T_0d79b_row7_col1, #T_0d79b_row8_col1, #T_0d79b_row9_col1, #T_0d79b_row10_col1, #T_0d79b_row11_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 100.0%, transparent 100.0%);
# }
# #T_0d79b_row12_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 97.1%, transparent 97.1%);
# }
# #T_0d79b_row13_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 89.1%, transparent 89.1%);
# }
# #T_0d79b_row14_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 87.4%, transparent 87.4%);
# }
# #T_0d79b_row15_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 82.1%, transparent 82.1%);
# }
# #T_0d79b_row16_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 81.7%, transparent 81.7%);
# }
# #T_0d79b_row17_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 77.2%, transparent 77.2%);
# }
# #T_0d79b_row18_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 72.5%, transparent 72.5%);
# }
# #T_0d79b_row19_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 72.1%, transparent 72.1%);
# }
# #T_0d79b_row20_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 70.2%, transparent 70.2%);
# }
# #T_0d79b_row21_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 68.9%, transparent 68.9%);
# }
# #T_0d79b_row22_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 68.5%, transparent 68.5%);
# }
# #T_0d79b_row23_col1, #T_0d79b_row24_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 65.7%, transparent 65.7%);
# }
# #T_0d79b_row25_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 63.7%, transparent 63.7%);
# }
# #T_0d79b_row26_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 61.6%, transparent 61.6%);
# }
# #T_0d79b_row27_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 61.5%, transparent 61.5%);
# }
# #T_0d79b_row28_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 60.7%, transparent 60.7%);
# }
# #T_0d79b_row29_col1, #T_0d79b_row30_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 60.1%, transparent 60.1%);
# }
# #T_0d79b_row31_col1, #T_0d79b_row32_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 58.6%, transparent 58.6%);
# }
# #T_0d79b_row33_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 56.9%, transparent 56.9%);
# }
# #T_0d79b_row34_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 56.8%, transparent 56.8%);
# }
# #T_0d79b_row35_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 56.0%, transparent 56.0%);
# }
# #T_0d79b_row36_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 55.7%, transparent 55.7%);
# }
# #T_0d79b_row37_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 55.6%, transparent 55.6%);
# }
# #T_0d79b_row38_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 47.5%, transparent 47.5%);
# }
# #T_0d79b_row39_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 45.8%, transparent 45.8%);
# }
# #T_0d79b_row40_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 31.9%, transparent 31.9%);
# }
# #T_0d79b_row41_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 15.9%, transparent 15.9%);
# }
# #T_0d79b_row42_col1, #T_0d79b_row43_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 14.5%, transparent 14.5%);
# }
# #T_0d79b_row44_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 10.4%, transparent 10.4%);
# }
# </style>
# <table id="T_0d79b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0d79b_level0_col0" class="col_heading level0 col0" >Coluna</th>
#       <th id="T_0d79b_level0_col1" class="col_heading level0 col1" >Preenchimento (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0d79b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0d79b_row0_col0" class="data row0 col0" >BB_UID</td>
#       <td id="T_0d79b_row0_col1" class="data row0 col1" >100.00%</td>
#     </tr>
#     <tr>
#       <th id="T_0d79b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0d79b_row1_col0" class="data row1 col0" >Platform_Content_ID</td>
#       <td id="T_0d79b_row1_col1" class="data row1 col1" >100.00%</td>
#     </tr>
#     <tr>
#       <th id="T_0d79b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0d79b_row2_col0" class="data row2 col0" >BB_Hash_Unique</td>
#       <td id="T_0d79b_row2_col1" class="data row2 col1" >100.00%</td>
#     </tr>
#     <tr>
#       <th id="T_0d79b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0d79b_row3_col0" class="data row3 col0" >Platform_Name</td>
#       <td id="T_0d79b_row3_col1" class="data row3 col1" >100.00%</td>
#     </tr>
#     <tr>
#       <th id="T_0d79b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0d79b_row4_col0" class="data row4 col0" >Platform_Country</td>
#       <td id="T_0d79b_row4_col1" class="data row4 col1" >100.00%</td>
#     </tr>
#     <tr>
#       <th id="T_0d79b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0d79b_row5_col0" class="data row5 col0" >Package</td>
#       <td id="T_0d79b_row5_col1" class="data row5 col1" >100.00%</td>
#     </tr>
#     <tr>
#       <th id="T_0d79b_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_0d79b_row6_col0" class="data row6 col0" >Type</td>
#       <td id="T_0d79b_row6_col1" class="data row6 col1" >100.00%</td>
#     </tr>
#     <tr>
#       <th id="T_0d79b_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_0d79b_row7_col0" class="data row7 col0" >Deeplink</td>
#       <td id="T_0d79b_row7_col1" class="data row7 col1" >100.00%</td>
#     </tr>
#     <tr>
#       <th id="T_0d79b_level0_row8" class="row_heading level0 row8" >10</th>
#       <td id="T_0d79b_row8_col0" class="data row8 col0" >Is_Original</td>
#       <td id="T_0d79b_row8_col1" class="data row8 col1" >100.00%</td>
#     </tr>
#     <tr>
#       <th id="T_0d79b_level0_row9" class="row_heading level0 row9" >11</th>
#       <td id="T_0d79b_row9_col0" class="data row9 col0" >Is_Exclusive</td>
#       <td id="T_0d79b_row9_col1" class="data row9 col1" >100.00%</td>
#     </tr>
#     <tr>
#       <th id="T_0d79b_level0_row10" class="row_heading level0 row10" >40</th>
#       <td id="T_0d79b_row10_col0" class="data row10 col0" >data_ref</td>
#       <td id="T_0d79b_row10_col1" class="data row10 col1" >100.00%</td>
#     </tr>
#     <tr>
#       <th id="T_0d79b_level0_row11" class="row_heading level0 row11" >6</th>
#       <td id="T_0d79b_row11_col0" class="data row11 col0" >Platform_Title</td>
#       <td id="T_0d79b_row11_col1" class="data row11 col1" >100.00%</td>
#     </tr>
#     <tr>
#       <th id="T_0d79b_level0_row12" class="row_heading level0 row12" >20</th>
#       <td id="T_0d79b_row12_col0" class="data row12 col0" >BB_Title</td>
#       <td id="T_0d79b_row12_col1" class="data row12 col1" >97.05%</td>
#     </tr>
#     <tr>
#       <th id="T_0d79b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_0d79b_row13_col0" class="data row13 col0" >Platform_Year</td>
#       <td id="T_0d79b_row13_col1" class="data row13 col1" >89.10%</td>
#     </tr>
#     <tr>
#       <th id="T_0d79b_level0_row14" class="row_heading level0 row14" >23</th>
#       <td id="T_0d79b_row14_col0" class="data row14 col0" >BB_Duration</td>
#       <td id="T_0d79b_row14_col1" class="data row14 col1" >87.37%</td>
#     </tr>
#     <tr>
#       <th id="T_0d79b_level0_row15" class="row_heading level0 row15" >44</th>
#       <td id="T_0d79b_row15_col0" class="data row15 col0" >BB_Coverage_In_Days</td>
#       <td id="T_0d79b_row15_col1" class="data row15 col1" >82.14%</td>
#     </tr>
#     <tr>
#       <th id="T_0d79b_level0_row16" class="row_heading level0 row16" >14</th>
#       <td id="T_0d79b_row16_col0" class="data row16 col0" >Platform_Duration</td>
#       <td id="T_0d79b

# %%
print("\n" + "="*80)
print(" ANÁLISE EXPLORATÓRIA 2: ESTABILIDADE DAS COLUNAS")
print("="*80)
print("Analisando a variabilidade dos metadados por BB_UID...")

try:
    con = duckdb.connect(database=':memory:')
    
    # Pega todas as colunas exceto as de controle
    colunas_para_analise = [col for col in colunas if col not in ['BB_UID', 'data_ref', 'arquivo_origem']]
    
    # Monta a query para contar valores distintos por UID para cada coluna
    agregacoes_distinct = [f'COUNT(DISTINCT \"{col}\") AS {col}' for col in colunas_para_analise]
    query_estabilidade = f"""
    SELECT
        {', '.join(agregacoes_distinct)}
    FROM
        read_parquet('{str(ARQUIVO_DE_ENTRADA)}')
    GROUP BY
        "BB_UID"
    """
    
    df_contagens = con.execute(query_estabilidade).fetch_df()
    
    # Calcula o percentual de UIDs que possuem mais de 1 valor para cada coluna
    metricas_estabilidade = []
    for col in df_contagens.columns:
        uids_inconsistentes = (df_contagens[col] > 1).sum()
        pct_inconsistente = 100.0 * uids_inconsistentes / len(df_contagens)
        metricas_estabilidade.append({"Coluna": col, "% de UIDs com >1 Valor": pct_inconsistente})
        
    df_estabilidade = pd.DataFrame(metricas_estabilidade).sort_values(by="% de UIDs com >1 Valor", ascending=True)

    display(HTML("<h4>Relatório de Estabilidade de Colunas</h4><p>Quanto menor o percentual, mais estável (confiável) é a coluna.</p>"))
    display(df_estabilidade.style.format({'% de UIDs com >1 Valor': '{:.2f}%'})
            .background_gradient(cmap='Greens_r', subset=['% de UIDs com >1 Valor']))

    con.close()
except Exception as e:
    print(f"ERRO durante a análise de estabilidade: {e}")
    if 'con' in locals(): con.close()
# Out:
# ================================================================================
#  ANÁLISE EXPLORATÓRIA 2: ESTABILIDADE DAS COLUNAS
# ================================================================================
# Analisando a variabilidade dos metadados por BB_UID...
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# <h4>Relatório de Estabilidade de Colunas</h4><p>Quanto menor o percentual, mais estável (confiável) é a coluna.</p>
# <style type="text/css">
# #T_437a4_row0_col1, #T_437a4_row1_col1, #T_437a4_row2_col1, #T_437a4_row3_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_437a4_row4_col1 {
#   background-color: #00451c;
#   color: #f1f1f1;
# }
# #T_437a4_row5_col1 {
#   background-color: #00481d;
#   color: #f1f1f1;
# }
# #T_437a4_row6_col1 {
#   background-color: #004d1f;
#   color: #f1f1f1;
# }
# #T_437a4_row7_col1 {
#   background-color: #005020;
#   color: #f1f1f1;
# }
# #T_437a4_row8_col1 {
#   background-color: #005321;
#   color: #f1f1f1;
# }
# #T_437a4_row9_col1, #T_437a4_row10_col1, #T_437a4_row11_col1 {
#   background-color: #005924;
#   color: #f1f1f1;
# }
# #T_437a4_row12_col1 {
#   background-color: #005b25;
#   color: #f1f1f1;
# }
# #T_437a4_row13_col1 {
#   background-color: #005c25;
#   color: #f1f1f1;
# }
# #T_437a4_row14_col1, #T_437a4_row15_col1 {
#   background-color: #006428;
#   color: #f1f1f1;
# }
# #T_437a4_row16_col1, #T_437a4_row17_col1 {
#   background-color: #00682a;
#   color: #f1f1f1;
# }
# #T_437a4_row18_col1 {
#   background-color: #006d2c;
#   color: #f1f1f1;
# }
# #T_437a4_row19_col1 {
#   background-color: #087432;
#   color: #f1f1f1;
# }
# #T_437a4_row20_col1 {
#   background-color: #097532;
#   color: #f1f1f1;
# }
# #T_437a4_row21_col1 {
#   background-color: #0a7633;
#   color: #f1f1f1;
# }
# #T_437a4_row22_col1 {
#   background-color: #0b7734;
#   color: #f1f1f1;
# }
# #T_437a4_row23_col1 {
#   background-color: #0c7735;
#   color: #f1f1f1;
# }
# #T_437a4_row24_col1 {
#   background-color: #107a37;
#   color: #f1f1f1;
# }
# #T_437a4_row25_col1 {
#   background-color: #19833e;
#   color: #f1f1f1;
# }
# #T_437a4_row26_col1 {
#   background-color: #1a843f;
#   color: #f1f1f1;
# }
# #T_437a4_row27_col1 {
#   background-color: #1c8540;
#   color: #f1f1f1;
# }
# #T_437a4_row28_col1 {
#   background-color: #1e8741;
#   color: #f1f1f1;
# }
# #T_437a4_row29_col1 {
#   background-color: #218944;
#   color: #f1f1f1;
# }
# #T_437a4_row30_col1 {
#   background-color: #268e47;
#   color: #f1f1f1;
# }
# #T_437a4_row31_col1, #T_437a4_row32_col1 {
#   background-color: #289049;
#   color: #f1f1f1;
# }
# #T_437a4_row33_col1 {
#   background-color: #2c944c;
#   color: #f1f1f1;
# }
# #T_437a4_row34_col1 {
#   background-color: #359e53;
#   color: #f1f1f1;
# }
# #T_437a4_row35_col1, #T_437a4_row36_col1 {
#   background-color: #3aa357;
#   color: #f1f1f1;
# }
# #T_437a4_row37_col1 {
#   background-color: #3ea75a;
#   color: #f1f1f1;
# }
# #T_437a4_row38_col1 {
#   background-color: #3fa95c;
#   color: #f1f1f1;
# }
# #T_437a4_row39_col1 {
#   background-color: #43ac5e;
#   color: #f1f1f1;
# }
# #T_437a4_row40_col1 {
#   background-color: #dbf1d6;
#   color: #000000;
# }
# #T_437a4_row41_col1 {
#   background-color: #e0f3db;
#   color: #000000;
# }
# #T_437a4_row42_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_437a4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_437a4_level0_col0" class="col_heading level0 col0" >Coluna</th>
#       <th id="T_437a4_level0_col1" class="col_heading level0 col1" >% de UIDs com >1 Valor</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_437a4_level0_row0" class="row_heading level0 row0" >40</th>
#       <td id="T_437a4_row0_col0" class="data row0 col0" >BB_Launch_Date</td>
#       <td id="T_437a4_row0_col1" class="data row0 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_437a4_level0_row1" class="row_heading level0 row1" >38</th>
#       <td id="T_437a4_row1_col0" class="data row1 col0" >IMDb_ID</td>
#       <td id="T_437a4_row1_col1" class="data row1 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_437a4_level0_row2" class="row_heading level0 row2" >36</th>
#       <td id="T_437a4_row2_col0" class="data row2 col0" >TMDB_ID</td>
#       <td id="T_437a4_row2_col1" class="data row2 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_437a4_level0_row3" class="row_heading level0 row3" >37</th>
#       <td id="T_437a4_row3_col0" class="data row3 col0" >TVDB_ID</td>
#       <td id="T_437a4_row3_col1" class="data row3 col1" >0.19%</td>
#     </tr>
#     <tr>
#       <th id="T_437a4_level0_row4" class="row_heading level0 row4" >21</th>
#       <td id="T_437a4_row4_col0" class="data row4 col0" >BB_Year</td>
#       <td id="T_437a4_row4_col1" class="data row4 col1" >0.73%</td>
#     </tr>
#     <tr>
#       <th id="T_437a4_level0_row5" class="row_heading level0 row5" >9</th>
#       <td id="T_437a4_row5_col0" class="data row5 col0" >Is_Original</td>
#       <td id="T_437a4_row5_col1" class="data row5 col1" >1.37%</td>
#     </tr>
#     <tr>
#       <th id="T_437a4_level0_row6" class="row_heading level0 row6" >26</th>
#       <td id="T_437a4_row6_col0" class="data row6 col0" >BB_Primary_Country</td>
#       <td id="T_437a4_row6_col1" class="data row6 col1" >2.61%</td>
#     </tr>
#     <tr>
#       <th id="T_437a4_level0_row7" class="row_heading level0 row7" >39</th>
#       <td id="T_437a4_row7_col0" class="data row7 col0" >Season_Numbers</td>
#       <td id="T_437a4_row7_col1" class="data row7 col1" >3.37%</td>
#     </tr>
#     <tr>
#       <th id="T_437a4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_437a4_row8_col0" class="data row8 col0" >Seasons</td>
#       <td id="T_437a4_row8_col1" class="data row8 col1" >4.55%</td>
#     </tr>
#     <tr>
#       <th id="T_437a4_level0_row9" class="row_heading level0 row9" >27</th>
#       <td id="T_437a4_row9_col0" class="data row9 col0" >BB_Countries</td>
#       <td id="T_437a4_row9_col1" class="data row9 col1" >5.91%</td>
#     </tr>
#     <tr>
#       <th id="T_437a4_level0_row10" class="row_heading level0 row10" >22</th>
#       <td id="T_437a4_row10_col0" class="data row10 col0" >BB_Duration</td>
#       <td id="T_437a4_row10_col1" class="data row10 col1" >5.99%</td>
#     </tr>
#     <tr>
#       <th id="T_437a4_level0_row11" class="row_heading level0 row11" >19</th>
#       <td id="T_437a4_row11_col0" class="data row11 col0" >BB_Title</td>
#       <td id="T_437a4_row11_col1" class="data row11 col1" >6.02%</td>
#     </tr>
#     <tr>
#       <th id="T_437a4_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_437a4_row12_col0" class="data row12 col0" >Platform_Year</td>
#       <td id="T_437a4_row12_col1" class="data row12 col1" >6.89%</td>
#     </tr>
#     <tr>
#       <th id="T_437a4_level0_row13" class="row_heading level0 row13" >11</th>
#       <td id="T_437a4_row13_col0" class="data row13 col0" >Episodes</td>
#       <td id="T_437a4_row13_col1" class="data row13 col1" >7.29%</td>
#     </tr>
#     <tr>
#       <th id="T_437a4_level0_row14" class="row_heading level0 row14" >17</th>
#       <td id="T_437a4_row14_col0" class="data row14 col0" >Platform_Directors</td>
#       <td id="T_437a4_row14_col1" class="data row14 col1" >9.18%</td>
#     </tr>
#     <tr>
#       <th id="T_437a4_level0_row15" class="row_heading level0 row15" >20</th>
#       <td id="T_437a4_row15_col0" class="data row15 col0" >BB_Original_Title</td>
#       <td id="T_437a4_row15_col1" class="data row15 col1" >9.26%</td>
#     </tr>
#     <tr>
#       <th id="T_437a4_level0_row16" class="row_heading level0 row16" >14</th>
#       <td id="T_437a4_row16_col0" class="data row16 col0" >Platform_Provider</td>
#       <td id="T_437a4_row16_col1" class="data row16 col1" >10.31%</td>
#     </tr>
#     <tr>
#       <th id="T_437a4_level0_row17" class="row_heading level0 row17" >13</th>
#       <td id="T_437a4_row17_col0" class="data row17 col0" >Platform_Duration</td>
#       <td id="T_437a4_row17_col1" class="data row17 col1" >10.53%</td>
#     </tr>
#     <tr>
#       <th id="T_437a4_level0_row18" class="row_heading level0 row18" >31</th>
#       <td id="T_437a4_row18_col0" class="data row18 col0" >BB_Directors</td>
#       <td id="T_437a4_row18_col1" class="data row18 col1" >11.71%</td>
#     </tr>
#     <tr>
#       <th id="T_437a4_level0_row19" class="row_heading level0 row19" >6</th>
#       <td id="T_437a4_row19_col0" class="data row19 col0" >Type</td>
#       <td id="T_437a4_row19_col1" class="data row19 col1" >14.50%</td>
#     </tr>
#     <tr>
#       <th id="T_437a4_level0_row20" class="row_heading level0 row20" >35</th>
#       <td id="T_437a4_row20_col0" class="data row20 col0" >BB_Score</td>
#       <td id="T_437a4_row20_col1" class="data row20 col1" >14.83%</td>
#     </tr>
#     <tr>
#       <th id="T_437a4_l

# %%
# ==============================================================================
# BLOCO DE DECISÃO: Sua seleção de colunas foi aplicada.
# ==============================================================================
# A lista abaixo foi criada a partir da sua análise e da imagem fornecida.
# Estas são as colunas que irão compor a nossa Tabela Dimensão.

COLUNAS_PARA_SPLINK = [
    # --- Identificação Essencial ---
    "BB_UID",
    "Type",
    
    # --- Metadados Principais da Obra (FICA) ---
    "BB_Title",
    "BB_Year",
    "BB_Duration",
    "BB_Genres",
    "BB_Directors",
    "BB_Original_Title",
    "IMDb_ID",
    "BB_Countries",
    "BB_Primary_Country",
    "BB_Production_Companies",
    "BB_Primary_Company",
    "TMDB_ID",
    "BB_Cast"
]

print("As seguintes colunas foram selecionadas para a criação da Tabela Dimensão:")
print(textwrap.fill(", ".join(COLUNAS_PARA_SPLINK), 80))
# Out:
# As seguintes colunas foram selecionadas para a criação da Tabela Dimensão:
# BB_UID, Type, BB_Title, BB_Year, BB_Duration, BB_Genres, BB_Directors,
# BB_Original_Title, IMDb_ID, BB_Countries, BB_Primary_Country,
# BB_Production_Companies, BB_Primary_Company, TMDB_ID, BB_Cast

# %%
# --- Funções Auxiliares de Limpeza (pré-Splink) ---
def normalizar_string(texto):
    """Aplica limpeza segura em um campo de texto: minúsculas, remove acentos e espaços extras."""
    if texto is None or pd.isna(texto):
        return None
    texto = str(texto).lower()
    texto = unidecode.unidecode(texto)
    return texto.strip()

def normalizar_lista_em_string(texto, separador=','):
    """Normaliza uma string que representa uma lista (ex: elenco, diretores)."""
    if texto is None or pd.isna(texto):
        return None
    nomes = str(texto).split(separador)
    nomes_limpos = sorted([normalizar_string(nome) for nome in nomes if str(nome).strip()])
    return separador.join(nomes_limpos) if nomes_limpos else None

# %%
# ==============================================================================
# BLOCO 5: EXECUÇÃO FINAL - Construção da Tabela Dimensão
# ==============================================================================
print("\n" + "="*80)
print(" EXECUÇÃO FINAL: CONSTRUÇÃO DA TABELA DIMENSÃO")
print("="*80)

try:
    con = duckdb.connect(database=':memory:')
    
    # A query agora usa a lista COLUNAS_PARA_SPLINK que você definiu no bloco anterior
    # e a lista de semanas que já havíamos definido
    colunas_selecionadas_sql = ", ".join([f'"{c}"' for c in COLUNAS_PARA_SPLINK + ['data_ref']])
    
    query_crunch_temporal = f"""
    WITH dados_filtrados AS (
        SELECT {colunas_selecionadas_sql}
        FROM read_parquet('{str(ARQUIVO_DE_ENTRADA)}')
        WHERE data_ref NOT IN {tuple(SEMANAS_A_EXCLUIR) if SEMANAS_A_EXCLUIR else '()'}
    ),
    ranking_por_data AS (
        SELECT *, ROW_NUMBER() OVER(PARTITION BY "BB_UID" ORDER BY data_ref DESC) as rn
        FROM dados_filtrados
    )
    SELECT {', '.join([f'"{c}"' for c in COLUNAS_PARA_SPLINK])}
    FROM ranking_por_data
    WHERE rn = 1
    """

    print("\nExecutando o 'crunch temporal' para criar os perfis únicos...")
    con.execute(f"COPY ({query_crunch_temporal}) TO '{str(ARQUIVO_DE_SAIDA)}' (FORMAT PARQUET, COMPRESSION 'snappy');")
    print(f"\n✔ Tabela dimensão criada com sucesso em: '{ARQUIVO_DE_SAIDA}'")
    
    df_resultado = con.execute(f"SELECT COUNT(*) as total_perfis_unicos FROM '{ARQUIVO_DE_SAIDA}'").fetch_df()
    total_perfis = df_resultado['total_perfis_unicos'].iloc[0]
    
    print(f"\n--- Resumo da Operação ---")
    print(f"  - Perfis únicos na Tabela Dimensão final: {total_perfis:,}")
    
    display(HTML("<h4>Amostra da Tabela Dimensão Gerada:</h4>"))
    display(con.execute(f"SELECT * FROM '{ARQUIVO_DE_SAIDA}' LIMIT 10").fetch_df())
    
    con.close()
    print("\nProcesso concluído.")

except Exception as e:
    print(f"\nOcorreu um erro durante o processo: {e}")
    if 'con' in locals():
        con.close()
# Out:
# ================================================================================
#  EXECUÇÃO FINAL: CONSTRUÇÃO DA TABELA DIMENSÃO
# ================================================================================
#
# Executando o 'crunch temporal' para criar os perfis únicos...
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# ✔ Tabela dimensão criada com sucesso em: 'dados_catalogo\processed\tabela_dimensao_splink.parquet'
#
# --- Resumo da Operação ---
#   - Perfis únicos na Tabela Dimensão final: 225,117
# <h4>Amostra da Tabela Dimensão Gerada:</h4>
#                              BB_UID    Type  \
# 0  445d312e8a15c1e5b6d83a9bd66879a4  Series
# 1  449425b8c5e58b376a6b4243a243cb3b  Series
# 2  449e9b567bda9d6972bc3085288bb22f   Movie
# 3  44bb2a4e73e311a1e88fc4227a1e3da0   Movie
# 4  44d59e5e804afee401af01ae22f0e835   Movie
# 5  4528ba9db05a36a47d9365bad4038fa5   Movie
# 6  454134cb25befa1b10a8f9dcd656aa2a   Movie
# 7  4575c4b5a775cc2614bb4c0c4f416b2c   Movie
# 8  45a45e5aa30f69307dced5fc00da45b3  Series
# 9  46368e888c1363d2dedd23bc87c89409   Movie
#
#                                             BB_Title  BB_Year  BB_Duration  \
# 0                            I Am Not Okay with This   2020.0         23.0
# 1  Alan Gilbert and Wenzel Fuchs with Mozart’s Cl...   2018.0          NaN
# 2                                              Azadi   2025.0        129.0
# 3  Austrália v Brasil | Disputa do 3º lugar | FIF...   2001.0          NaN
# 4                                         On Our Own   2010.0         21.0
# 5      Free Jazz in Kongressaal Munich: Cecil Taylor   1984.0         55.0
# 6                    Ding Dong Bell - Pop Rock Style   2016.0          1.0
# 7                                    LINA WERTMÜLLER   2017.0         24.0
# 8                               Legend of the Dragon   2006.0         24.0
# 9                                          DET @ CHI   2014.0        130.0
#
#                                        BB_Genres           BB_Directors  \
# 0                 Sci-fi, Comedy, Fantasy, Drama     Jonathan Entwistle
# 1                                           None           Alan Gilbert
# 2                                Drama, Thriller             Joe George
# 3                                           None                   None
# 4                             Documentary, Short           Camiel Zwart
# 5                                           None           János Darvas
# 6                                           None                    A,N
# 7                                           None  Serena Ucelli Di Nemi
# 8  Animation, Action, Adventure, Fantasy, Sci-fi       Tom Tataranowicz
# 9                                           None                   None
#
#          BB_Original_Title     IMDb_ID    BB_Countries BB_Primary_Country  \
# 0  I Am Not Okay with This   tt9446688              US                 US
# 1                     None        None            None               None
# 2                    Azadi  tt27494358              IN                 IN
# 3                     None        None            None               None
# 4               On Our Own   tt1764532              NL                 NL
# 5                     None        None            None               None
# 6                     None        None            None               None
# 7                     None        None            None               None
# 8     Legend of the Dragon   tt0776469  HK, US, GB, DE                 GB
# 9                     None        None            None               None
#
#                              BB_Production_Companies  \
# 0  21 Laps Entertainment, Ceremony Pictures, Rain...
# 1                                               None
# 2                            Little Crew Productions
# 3                                               None
# 4                                               None
# 5                                               None
# 6                                               None
# 7                                               None
# 8     Sony Pictures Entertainment, Bkn International
# 9                                               None
#
#             BB_Primary_Company    TMDB_ID  \
# 0        21 Laps Entertainment    90260.0
# 1                         None        NaN
# 2      Little Crew Productions  1115022.0
# 3                         None        NaN
# 4                         None   660350.0
# 5                         None        NaN
# 6                         None        NaN
# 7                         None        NaN
# 8  Sony Pictures Entertainment    16815.0
# 9                         None        NaN
#
#                                              BB_Cast
# 0  Sophia Lillis, Wyatt Oleff, Sofia Bryant, Kath...
# 1                                               None
# 2  Sreenath Bhasi, Raveena Ravi, Lal, Salim Kumar...
# 3                                               None
# 4                                               None
# 5                                               None
# 6                                               None
# 7                                               None
# 8  Marc Silk, Alan Marriott, Gary Martin, Larissa...
# 9                                               None
# Processo concluído.
