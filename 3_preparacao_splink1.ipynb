# %%
import pandas as pd
import pathlib
import duckdb
from IPython.display import display, HTML
import unidecode
import textwrap

# --- Parâmetros de Entrada ---
PASTA_PROCESSED = pathlib.Path("dados_catalogo") / "processed"
ARQUIVO_DE_ENTRADA = PASTA_PROCESSED / 'dados_consolidados_filtrados.parquet'
ARQUIVO_DE_SAIDA = PASTA_PROCESSED / 'tabela_dimensao_limpa_para_splink.parquet'

# --- Regras de Negócio Já Definidas ---
# Semanas a serem EXCLUÍDAS da análise de metadados, com base na nossa investigação.
SEMANAS_A_EXCLUIR = ['2024-10-25', '2024-11-21']

print("--- Etapa 3: Análise Exploratória e Preparação da Tabela Dimensão ---")
print("Bloco 1: Configurações carregadas.")
# Out:
# --- Etapa 3: Análise Exploratória e Preparação da Tabela Dimensão ---
# Bloco 1: Configurações carregadas.

# %%
print("\n" + "="*80)
print(" ANÁLISE EXPLORATÓRIA 1: COMPLETUDE DAS COLUNAS")
print("="*80)
print("Analisando o percentual de preenchimento (não-nulos) de cada coluna...")

try:
    con = duckdb.connect(database=':memory:')
    df_schema = con.execute(f"DESCRIBE SELECT * FROM read_parquet('{str(ARQUIVO_DE_ENTRADA)}');").fetch_df()
    colunas = df_schema['column_name'].tolist()
    
    metricas_completude = []
    for col in colunas:
        query = f"SELECT 100.0 * COUNT(\"{col}\") / COUNT(*) FROM read_parquet('{str(ARQUIVO_DE_ENTRADA)}');"
        pct_preenchimento = con.execute(query).fetchone()[0]
        metricas_completude.append({"Coluna": col, "Preenchimento (%)": pct_preenchimento})
        
    df_completude = pd.DataFrame(metricas_completude).sort_values(by="Preenchimento (%)", ascending=False)

    display(HTML("<h4>Relatório de Completude de Colunas</h4>"))
    display(df_completude.style.format({'Preenchimento (%)': '{:.2f}%'})
            .bar(subset=['Preenchimento (%)'], color='#5DADE2', vmin=0, vmax=100))
    
    con.close()
except Exception as e:
    print(f"ERRO durante a análise de completude: {e}")
    if 'con' in locals(): con.close()
# Out:
# ================================================================================
#  ANÁLISE EXPLORATÓRIA 1: COMPLETUDE DAS COLUNAS
# ================================================================================
# Analisando o percentual de preenchimento (não-nulos) de cada coluna...
# <h4>Relatório de Completude de Colunas</h4>
# <style type="text/css">
# #T_5d7b7_row0_col1, #T_5d7b7_row1_col1, #T_5d7b7_row2_col1, #T_5d7b7_row3_col1, #T_5d7b7_row4_col1, #T_5d7b7_row5_col1, #T_5d7b7_row6_col1, #T_5d7b7_row7_col1, #T_5d7b7_row8_col1, #T_5d7b7_row9_col1, #T_5d7b7_row10_col1, #T_5d7b7_row11_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 100.0%, transparent 100.0%);
# }
# #T_5d7b7_row12_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 97.1%, transparent 97.1%);
# }
# #T_5d7b7_row13_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 89.1%, transparent 89.1%);
# }
# #T_5d7b7_row14_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 87.4%, transparent 87.4%);
# }
# #T_5d7b7_row15_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 82.1%, transparent 82.1%);
# }
# #T_5d7b7_row16_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 81.7%, transparent 81.7%);
# }
# #T_5d7b7_row17_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 77.2%, transparent 77.2%);
# }
# #T_5d7b7_row18_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 72.5%, transparent 72.5%);
# }
# #T_5d7b7_row19_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 72.1%, transparent 72.1%);
# }
# #T_5d7b7_row20_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 70.2%, transparent 70.2%);
# }
# #T_5d7b7_row21_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 68.9%, transparent 68.9%);
# }
# #T_5d7b7_row22_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 68.5%, transparent 68.5%);
# }
# #T_5d7b7_row23_col1, #T_5d7b7_row24_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 65.7%, transparent 65.7%);
# }
# #T_5d7b7_row25_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 63.7%, transparent 63.7%);
# }
# #T_5d7b7_row26_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 61.6%, transparent 61.6%);
# }
# #T_5d7b7_row27_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 61.5%, transparent 61.5%);
# }
# #T_5d7b7_row28_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 60.7%, transparent 60.7%);
# }
# #T_5d7b7_row29_col1, #T_5d7b7_row30_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 60.1%, transparent 60.1%);
# }
# #T_5d7b7_row31_col1, #T_5d7b7_row32_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 58.6%, transparent 58.6%);
# }
# #T_5d7b7_row33_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 56.9%, transparent 56.9%);
# }
# #T_5d7b7_row34_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 56.8%, transparent 56.8%);
# }
# #T_5d7b7_row35_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 56.0%, transparent 56.0%);
# }
# #T_5d7b7_row36_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 55.7%, transparent 55.7%);
# }
# #T_5d7b7_row37_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 55.6%, transparent 55.6%);
# }
# #T_5d7b7_row38_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 47.5%, transparent 47.5%);
# }
# #T_5d7b7_row39_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 45.8%, transparent 45.8%);
# }
# #T_5d7b7_row40_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 31.9%, transparent 31.9%);
# }
# #T_5d7b7_row41_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 15.9%, transparent 15.9%);
# }
# #T_5d7b7_row42_col1, #T_5d7b7_row43_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 14.5%, transparent 14.5%);
# }
# #T_5d7b7_row44_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5DADE2 10.4%, transparent 10.4%);
# }
# </style>
# <table id="T_5d7b7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5d7b7_level0_col0" class="col_heading level0 col0" >Coluna</th>
#       <th id="T_5d7b7_level0_col1" class="col_heading level0 col1" >Preenchimento (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5d7b7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5d7b7_row0_col0" class="data row0 col0" >BB_UID</td>
#       <td id="T_5d7b7_row0_col1" class="data row0 col1" >100.00%</td>
#     </tr>
#     <tr>
#       <th id="T_5d7b7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5d7b7_row1_col0" class="data row1 col0" >Platform_Content_ID</td>
#       <td id="T_5d7b7_row1_col1" class="data row1 col1" >100.00%</td>
#     </tr>
#     <tr>
#       <th id="T_5d7b7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5d7b7_row2_col0" class="data row2 col0" >BB_Hash_Unique</td>
#       <td id="T_5d7b7_row2_col1" class="data row2 col1" >100.00%</td>
#     </tr>
#     <tr>
#       <th id="T_5d7b7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5d7b7_row3_col0" class="data row3 col0" >Platform_Name</td>
#       <td id="T_5d7b7_row3_col1" class="data row3 col1" >100.00%</td>
#     </tr>
#     <tr>
#       <th id="T_5d7b7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5d7b7_row4_col0" class="data row4 col0" >Platform_Country</td>
#       <td id="T_5d7b7_row4_col1" class="data row4 col1" >100.00%</td>
#     </tr>
#     <tr>
#       <th id="T_5d7b7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5d7b7_row5_col0" class="data row5 col0" >Package</td>
#       <td id="T_5d7b7_row5_col1" class="data row5 col1" >100.00%</td>
#     </tr>
#     <tr>
#       <th id="T_5d7b7_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_5d7b7_row6_col0" class="data row6 col0" >Type</td>
#       <td id="T_5d7b7_row6_col1" class="data row6 col1" >100.00%</td>
#     </tr>
#     <tr>
#       <th id="T_5d7b7_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_5d7b7_row7_col0" class="data row7 col0" >Deeplink</td>
#       <td id="T_5d7b7_row7_col1" class="data row7 col1" >100.00%</td>
#     </tr>
#     <tr>
#       <th id="T_5d7b7_level0_row8" class="row_heading level0 row8" >10</th>
#       <td id="T_5d7b7_row8_col0" class="data row8 col0" >Is_Original</td>
#       <td id="T_5d7b7_row8_col1" class="data row8 col1" >100.00%</td>
#     </tr>
#     <tr>
#       <th id="T_5d7b7_level0_row9" class="row_heading level0 row9" >11</th>
#       <td id="T_5d7b7_row9_col0" class="data row9 col0" >Is_Exclusive</td>
#       <td id="T_5d7b7_row9_col1" class="data row9 col1" >100.00%</td>
#     </tr>
#     <tr>
#       <th id="T_5d7b7_level0_row10" class="row_heading level0 row10" >40</th>
#       <td id="T_5d7b7_row10_col0" class="data row10 col0" >data_ref</td>
#       <td id="T_5d7b7_row10_col1" class="data row10 col1" >100.00%</td>
#     </tr>
#     <tr>
#       <th id="T_5d7b7_level0_row11" class="row_heading level0 row11" >6</th>
#       <td id="T_5d7b7_row11_col0" class="data row11 col0" >Platform_Title</td>
#       <td id="T_5d7b7_row11_col1" class="data row11 col1" >100.00%</td>
#     </tr>
#     <tr>
#       <th id="T_5d7b7_level0_row12" class="row_heading level0 row12" >20</th>
#       <td id="T_5d7b7_row12_col0" class="data row12 col0" >BB_Title</td>
#       <td id="T_5d7b7_row12_col1" class="data row12 col1" >97.05%</td>
#     </tr>
#     <tr>
#       <th id="T_5d7b7_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_5d7b7_row13_col0" class="data row13 col0" >Platform_Year</td>
#       <td id="T_5d7b7_row13_col1" class="data row13 col1" >89.10%</td>
#     </tr>
#     <tr>
#       <th id="T_5d7b7_level0_row14" class="row_heading level0 row14" >23</th>
#       <td id="T_5d7b7_row14_col0" class="data row14 col0" >BB_Duration</td>
#       <td id="T_5d7b7_row14_col1" class="data row14 col1" >87.37%</td>
#     </tr>
#     <tr>
#       <th id="T_5d7b7_level0_row15" class="row_heading level0 row15" >44</th>
#       <td id="T_5d7b7_row15_col0" class="data row15 col0" >BB_Coverage_In_Days</td>
#       <td id="T_5d7b7_row15_col1" class="data row15 col1" >82.14%</td>
#     </tr>
#     <tr>
#       <th id="T_5d7b7_level0_row16" class="row_heading level0 row16" >14</th>
#       <td id="T_5d7b7_row16_col0" class="data row16 col0" >Platform_Duration</td>
#       <td id="T_5d7b7

# %%
print("\n" + "="*80)
print(" ANÁLISE EXPLORATÓRIA 2: ESTABILIDADE DAS COLUNAS")
print("="*80)
print("Analisando a variabilidade dos metadados por BB_UID...")

try:
    con = duckdb.connect(database=':memory:')
    
    # Pega todas as colunas exceto as de controle
    colunas_para_analise = [col for col in colunas if col not in ['BB_UID', 'data_ref', 'arquivo_origem']]
    
    # Monta a query para contar valores distintos por UID para cada coluna
    agregacoes_distinct = [f'COUNT(DISTINCT \"{col}\") AS {col}' for col in colunas_para_analise]
    query_estabilidade = f"""
    SELECT
        {', '.join(agregacoes_distinct)}
    FROM
        read_parquet('{str(ARQUIVO_DE_ENTRADA)}')
    GROUP BY
        "BB_UID"
    """
    
    df_contagens = con.execute(query_estabilidade).fetch_df()
    
    # Calcula o percentual de UIDs que possuem mais de 1 valor para cada coluna
    metricas_estabilidade = []
    for col in df_contagens.columns:
        uids_inconsistentes = (df_contagens[col] > 1).sum()
        pct_inconsistente = 100.0 * uids_inconsistentes / len(df_contagens)
        metricas_estabilidade.append({"Coluna": col, "% de UIDs com >1 Valor": pct_inconsistente})
        
    df_estabilidade = pd.DataFrame(metricas_estabilidade).sort_values(by="% de UIDs com >1 Valor", ascending=True)

    display(HTML("<h4>Relatório de Estabilidade de Colunas</h4><p>Quanto menor o percentual, mais estável (confiável) é a coluna.</p>"))
    display(df_estabilidade.style.format({'% de UIDs com >1 Valor': '{:.2f}%'})
            .background_gradient(cmap='Greens_r', subset=['% de UIDs com >1 Valor']))

    con.close()
except Exception as e:
    print(f"ERRO durante a análise de estabilidade: {e}")
    if 'con' in locals(): con.close()
# Out:
# ================================================================================
#  ANÁLISE EXPLORATÓRIA 2: ESTABILIDADE DAS COLUNAS
# ================================================================================
# Analisando a variabilidade dos metadados por BB_UID...
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# <h4>Relatório de Estabilidade de Colunas</h4><p>Quanto menor o percentual, mais estável (confiável) é a coluna.</p>
# <style type="text/css">
# #T_ced38_row0_col1, #T_ced38_row1_col1, #T_ced38_row2_col1, #T_ced38_row3_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_ced38_row4_col1 {
#   background-color: #00451c;
#   color: #f1f1f1;
# }
# #T_ced38_row5_col1 {
#   background-color: #00481d;
#   color: #f1f1f1;
# }
# #T_ced38_row6_col1 {
#   background-color: #004d1f;
#   color: #f1f1f1;
# }
# #T_ced38_row7_col1 {
#   background-color: #005020;
#   color: #f1f1f1;
# }
# #T_ced38_row8_col1 {
#   background-color: #005321;
#   color: #f1f1f1;
# }
# #T_ced38_row9_col1, #T_ced38_row10_col1, #T_ced38_row11_col1 {
#   background-color: #005924;
#   color: #f1f1f1;
# }
# #T_ced38_row12_col1 {
#   background-color: #005b25;
#   color: #f1f1f1;
# }
# #T_ced38_row13_col1 {
#   background-color: #005c25;
#   color: #f1f1f1;
# }
# #T_ced38_row14_col1, #T_ced38_row15_col1 {
#   background-color: #006428;
#   color: #f1f1f1;
# }
# #T_ced38_row16_col1, #T_ced38_row17_col1 {
#   background-color: #00682a;
#   color: #f1f1f1;
# }
# #T_ced38_row18_col1 {
#   background-color: #006d2c;
#   color: #f1f1f1;
# }
# #T_ced38_row19_col1 {
#   background-color: #087432;
#   color: #f1f1f1;
# }
# #T_ced38_row20_col1 {
#   background-color: #097532;
#   color: #f1f1f1;
# }
# #T_ced38_row21_col1 {
#   background-color: #0a7633;
#   color: #f1f1f1;
# }
# #T_ced38_row22_col1 {
#   background-color: #0b7734;
#   color: #f1f1f1;
# }
# #T_ced38_row23_col1 {
#   background-color: #0c7735;
#   color: #f1f1f1;
# }
# #T_ced38_row24_col1 {
#   background-color: #107a37;
#   color: #f1f1f1;
# }
# #T_ced38_row25_col1 {
#   background-color: #19833e;
#   color: #f1f1f1;
# }
# #T_ced38_row26_col1 {
#   background-color: #1a843f;
#   color: #f1f1f1;
# }
# #T_ced38_row27_col1 {
#   background-color: #1c8540;
#   color: #f1f1f1;
# }
# #T_ced38_row28_col1 {
#   background-color: #1e8741;
#   color: #f1f1f1;
# }
# #T_ced38_row29_col1 {
#   background-color: #218944;
#   color: #f1f1f1;
# }
# #T_ced38_row30_col1 {
#   background-color: #268e47;
#   color: #f1f1f1;
# }
# #T_ced38_row31_col1, #T_ced38_row32_col1 {
#   background-color: #289049;
#   color: #f1f1f1;
# }
# #T_ced38_row33_col1 {
#   background-color: #2c944c;
#   color: #f1f1f1;
# }
# #T_ced38_row34_col1 {
#   background-color: #359e53;
#   color: #f1f1f1;
# }
# #T_ced38_row35_col1, #T_ced38_row36_col1 {
#   background-color: #3aa357;
#   color: #f1f1f1;
# }
# #T_ced38_row37_col1 {
#   background-color: #3ea75a;
#   color: #f1f1f1;
# }
# #T_ced38_row38_col1 {
#   background-color: #3fa95c;
#   color: #f1f1f1;
# }
# #T_ced38_row39_col1 {
#   background-color: #43ac5e;
#   color: #f1f1f1;
# }
# #T_ced38_row40_col1 {
#   background-color: #dbf1d6;
#   color: #000000;
# }
# #T_ced38_row41_col1 {
#   background-color: #e0f3db;
#   color: #000000;
# }
# #T_ced38_row42_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_ced38">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ced38_level0_col0" class="col_heading level0 col0" >Coluna</th>
#       <th id="T_ced38_level0_col1" class="col_heading level0 col1" >% de UIDs com >1 Valor</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ced38_level0_row0" class="row_heading level0 row0" >40</th>
#       <td id="T_ced38_row0_col0" class="data row0 col0" >BB_Launch_Date</td>
#       <td id="T_ced38_row0_col1" class="data row0 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_ced38_level0_row1" class="row_heading level0 row1" >38</th>
#       <td id="T_ced38_row1_col0" class="data row1 col0" >IMDb_ID</td>
#       <td id="T_ced38_row1_col1" class="data row1 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_ced38_level0_row2" class="row_heading level0 row2" >36</th>
#       <td id="T_ced38_row2_col0" class="data row2 col0" >TMDB_ID</td>
#       <td id="T_ced38_row2_col1" class="data row2 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_ced38_level0_row3" class="row_heading level0 row3" >37</th>
#       <td id="T_ced38_row3_col0" class="data row3 col0" >TVDB_ID</td>
#       <td id="T_ced38_row3_col1" class="data row3 col1" >0.19%</td>
#     </tr>
#     <tr>
#       <th id="T_ced38_level0_row4" class="row_heading level0 row4" >21</th>
#       <td id="T_ced38_row4_col0" class="data row4 col0" >BB_Year</td>
#       <td id="T_ced38_row4_col1" class="data row4 col1" >0.73%</td>
#     </tr>
#     <tr>
#       <th id="T_ced38_level0_row5" class="row_heading level0 row5" >9</th>
#       <td id="T_ced38_row5_col0" class="data row5 col0" >Is_Original</td>
#       <td id="T_ced38_row5_col1" class="data row5 col1" >1.37%</td>
#     </tr>
#     <tr>
#       <th id="T_ced38_level0_row6" class="row_heading level0 row6" >26</th>
#       <td id="T_ced38_row6_col0" class="data row6 col0" >BB_Primary_Country</td>
#       <td id="T_ced38_row6_col1" class="data row6 col1" >2.61%</td>
#     </tr>
#     <tr>
#       <th id="T_ced38_level0_row7" class="row_heading level0 row7" >39</th>
#       <td id="T_ced38_row7_col0" class="data row7 col0" >Season_Numbers</td>
#       <td id="T_ced38_row7_col1" class="data row7 col1" >3.37%</td>
#     </tr>
#     <tr>
#       <th id="T_ced38_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ced38_row8_col0" class="data row8 col0" >Seasons</td>
#       <td id="T_ced38_row8_col1" class="data row8 col1" >4.55%</td>
#     </tr>
#     <tr>
#       <th id="T_ced38_level0_row9" class="row_heading level0 row9" >27</th>
#       <td id="T_ced38_row9_col0" class="data row9 col0" >BB_Countries</td>
#       <td id="T_ced38_row9_col1" class="data row9 col1" >5.91%</td>
#     </tr>
#     <tr>
#       <th id="T_ced38_level0_row10" class="row_heading level0 row10" >22</th>
#       <td id="T_ced38_row10_col0" class="data row10 col0" >BB_Duration</td>
#       <td id="T_ced38_row10_col1" class="data row10 col1" >5.99%</td>
#     </tr>
#     <tr>
#       <th id="T_ced38_level0_row11" class="row_heading level0 row11" >19</th>
#       <td id="T_ced38_row11_col0" class="data row11 col0" >BB_Title</td>
#       <td id="T_ced38_row11_col1" class="data row11 col1" >6.02%</td>
#     </tr>
#     <tr>
#       <th id="T_ced38_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_ced38_row12_col0" class="data row12 col0" >Platform_Year</td>
#       <td id="T_ced38_row12_col1" class="data row12 col1" >6.89%</td>
#     </tr>
#     <tr>
#       <th id="T_ced38_level0_row13" class="row_heading level0 row13" >11</th>
#       <td id="T_ced38_row13_col0" class="data row13 col0" >Episodes</td>
#       <td id="T_ced38_row13_col1" class="data row13 col1" >7.29%</td>
#     </tr>
#     <tr>
#       <th id="T_ced38_level0_row14" class="row_heading level0 row14" >17</th>
#       <td id="T_ced38_row14_col0" class="data row14 col0" >Platform_Directors</td>
#       <td id="T_ced38_row14_col1" class="data row14 col1" >9.18%</td>
#     </tr>
#     <tr>
#       <th id="T_ced38_level0_row15" class="row_heading level0 row15" >20</th>
#       <td id="T_ced38_row15_col0" class="data row15 col0" >BB_Original_Title</td>
#       <td id="T_ced38_row15_col1" class="data row15 col1" >9.26%</td>
#     </tr>
#     <tr>
#       <th id="T_ced38_level0_row16" class="row_heading level0 row16" >14</th>
#       <td id="T_ced38_row16_col0" class="data row16 col0" >Platform_Provider</td>
#       <td id="T_ced38_row16_col1" class="data row16 col1" >10.31%</td>
#     </tr>
#     <tr>
#       <th id="T_ced38_level0_row17" class="row_heading level0 row17" >13</th>
#       <td id="T_ced38_row17_col0" class="data row17 col0" >Platform_Duration</td>
#       <td id="T_ced38_row17_col1" class="data row17 col1" >10.53%</td>
#     </tr>
#     <tr>
#       <th id="T_ced38_level0_row18" class="row_heading level0 row18" >31</th>
#       <td id="T_ced38_row18_col0" class="data row18 col0" >BB_Directors</td>
#       <td id="T_ced38_row18_col1" class="data row18 col1" >11.71%</td>
#     </tr>
#     <tr>
#       <th id="T_ced38_level0_row19" class="row_heading level0 row19" >6</th>
#       <td id="T_ced38_row19_col0" class="data row19 col0" >Type</td>
#       <td id="T_ced38_row19_col1" class="data row19 col1" >14.50%</td>
#     </tr>
#     <tr>
#       <th id="T_ced38_level0_row20" class="row_heading level0 row20" >35</th>
#       <td id="T_ced38_row20_col0" class="data row20 col0" >BB_Score</td>
#       <td id="T_ced38_row20_col1" class="data row20 col1" >14.83%</td>
#     </tr>
#     <tr>
#       <th id="T_ced38_l

# %%
# ==============================================================================
# BLOCO DE DECISÃO: Sua seleção de colunas foi aplicada.
# ==============================================================================
# A lista abaixo foi criada a partir da sua análise e da imagem fornecida.
# Estas são as colunas que irão compor a nossa Tabela Dimensão.

COLUNAS_PARA_SPLINK = [
    # --- Identificação Essencial ---
    "BB_UID",
    "Type",
    
    # --- Metadados Principais da Obra (FICA) ---
    "BB_Title",
    "BB_Year",
    "BB_Duration",
    "BB_Genres",
    "BB_Directors",
    "BB_Original_Title",
    "IMDb_ID",
    "BB_Countries",
    "BB_Primary_Country",
    "BB_Production_Companies",
    "BB_Primary_Company",
    "TMDB_ID",
    "BB_Cast"
]

print("As seguintes colunas foram selecionadas para a criação da Tabela Dimensão:")
print(textwrap.fill(", ".join(COLUNAS_PARA_SPLINK), 80))
# Out:
# As seguintes colunas foram selecionadas para a criação da Tabela Dimensão:
# BB_UID, Type, BB_Title, BB_Year, BB_Duration, BB_Genres, BB_Directors,
# BB_Original_Title, IMDb_ID, BB_Countries, BB_Primary_Country,
# BB_Production_Companies, BB_Primary_Company, TMDB_ID, BB_Cast

# %%
# --- Funções Auxiliares de Limpeza (pré-Splink) ---
def normalizar_string(texto):
    """Aplica limpeza segura em um campo de texto: minúsculas, remove acentos e espaços extras."""
    if texto is None or pd.isna(texto):
        return None
    texto = str(texto).lower()
    texto = unidecode.unidecode(texto)
    return texto.strip()

def normalizar_lista_em_string(texto, separador=','):
    """Normaliza uma string que representa uma lista (ex: elenco, diretores)."""
    if texto is None or pd.isna(texto):
        return None
    nomes = str(texto).split(separador)
    nomes_limpos = sorted([normalizar_string(nome) for nome in nomes if str(nome).strip()])
    return separador.join(nomes_limpos) if nomes_limpos else None

# %%
# ==============================================================================
# BLOCO 5: EXECUÇÃO FINAL - Construção da Tabela Dimensão
# ==============================================================================
print("\n" + "="*80)
print(" EXECUÇÃO FINAL: CONSTRUÇÃO DA TABELA DIMENSÃO")
print("="*80)

try:
    con = duckdb.connect(database=':memory:')
    
    # A query agora usa a lista COLUNAS_PARA_SPLINK que você definiu no bloco anterior
    # e a lista de semanas que já havíamos definido
    colunas_selecionadas_sql = ", ".join([f'"{c}"' for c in COLUNAS_PARA_SPLINK + ['data_ref']])
    
    query_crunch_temporal = f"""
    WITH dados_filtrados AS (
        SELECT {colunas_selecionadas_sql}
        FROM read_parquet('{str(ARQUIVO_DE_ENTRADA)}')
        WHERE data_ref NOT IN {tuple(SEMANAS_A_EXCLUIR) if SEMANAS_A_EXCLUIR else '()'}
    ),
    ranking_por_data AS (
        SELECT *, ROW_NUMBER() OVER(PARTITION BY "BB_UID" ORDER BY data_ref DESC) as rn
        FROM dados_filtrados
    )
    SELECT {', '.join([f'"{c}"' for c in COLUNAS_PARA_SPLINK])}
    FROM ranking_por_data
    WHERE rn = 1
    """

    print("\nExecutando o 'crunch temporal' para criar os perfis únicos...")
    df_dim = con.execute(query_crunch_temporal).fetch_df()
    print(f"\n✔ Tabela dimensão criada com sucesso em: '{ARQUIVO_DE_SAIDA}'")
    
    total_perfis = len(df_dim)
    
    print(f"\n--- Resumo da Operação ---")
    print(f"  - Perfis únicos na Tabela Dimensão final: {total_perfis:,}")
    
    display(HTML("<h4>Amostra da Tabela Dimensão Gerada:</h4>"))
    display(df_dim.head(10))
    
    con.close()
    print("\nProcesso concluído.")

except Exception as e:
    print(f"\nOcorreu um erro durante o processo: {e}")
    if 'con' in locals():
        con.close()
# Out:
# ================================================================================
#  EXECUÇÃO FINAL: CONSTRUÇÃO DA TABELA DIMENSÃO
# ================================================================================
#
# Executando o 'crunch temporal' para criar os perfis únicos...
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# ✔ Tabela dimensão criada com sucesso em: 'dados_catalogo\processed\tabela_dimensao_limpa_para_splink.parquet'
#
# --- Resumo da Operação ---
#   - Perfis únicos na Tabela Dimensão final: 225,117
# <h4>Amostra da Tabela Dimensão Gerada:</h4>
#                              BB_UID    Type  \
# 0  00b77a05935019a6ad916b8b6d5f5eee   Movie
# 1  00bddd10545d483cd77f47c5b5ae47e1   Movie
# 2  00c539ccc6dc43d4712cda5d01c974f5   Movie
# 3  00d7c5bdb60afd7bdc08a3cd9eda8372  Series
# 4  00fb202cd659102231f50ae6d73dd1b5   Movie
# 5  01010cb1a71b8f2abb7bd1a002a7d8fc   Movie
# 6  01028430437153d18e47298566740802   Movie
# 7  011fe07e32ad9588a7c5422249d30e77   Movie
# 8  013ff47a3ab5e6df384f7a43975910b4   Movie
# 9  0151b846b0a4b4c78dfe573b9f309ff5   Movie
#
#                                             BB_Title  BB_Year  BB_Duration  \
# 0                                        Carl's Date   2023.0          9.0
# 1                         Live in the USA Uriah Heep   2003.0         83.0
# 2                       Whatever Happened to Gelitin   2016.0         82.0
# 3  Malaysia Astro Chinese International Pageant 2019   2019.0          NaN
# 4                                  See you in Denver   2006.0         52.0
# 5  Howard Hughes: The Great Aviator - His Life, L...   2004.0         73.0
# 6  School of Intelligent Faith - 27/10/21 - South...   2021.0         68.0
# 7                                Mensagens - Parte 1   2009.0         24.0
# 8                                   A Table of Three   2024.0         23.0
# 9                                 The King of Comedy   1982.0        109.0
#
#                                            BB_Genres  \
# 0  Comedy, Romance, Family, Adventure, Animation,...
# 1                                               None
# 2                                Comedy, Documentary
# 3                                               None
# 4                                               None
# 5                             Biography, Documentary
# 6                                               None
# 7                                           Suspense
# 8                                      Family, Drama
# 9                               Comedy, Drama, Crime
#
#                          BB_Directors  \
# 0                        Bob Peterson
# 1                                None
# 2                   Angela Christlieb
# 3                                None
# 4                            Jan Šikl
# 5                      Lynn Stevenson
# 6                    Universal Church
# 7           Fábio Vieira Rodrigues,Mg
# 8  Luthfi Ihza Mahendra,Irfan Maulana
# 9                     Martin Scorsese
#
#                                    BB_Original_Title     IMDb_ID BB_Countries  \
# 0                                        Carl's Date  tt26736061           US
# 1                                               None        None         None
# 2                       Whatever Happened to Gelitin   tt5669930      AT, AUT
# 3                                               None        None         None
# 4                                               None        None         None
# 5  Howard Hughes: The Great Aviator - His Life, L...   tt0430200           US
# 6                                               None        None         None
# 7                                               None        None         None
# 8                                               None        None         None
# 9                                 The King of Comedy   tt0085794           US
#
#   BB_Primary_Country                            BB_Production_Companies  \
# 0                 US  Pixar Animation Studios, Pixar, Walt Disney Pi...
# 1               None                                               None
# 2                 AT                                               None
# 3               None                                               None
# 4               None                                               None
# 5                 US                                               None
# 6               None                                               None
# 7               None                                               None
# 8               None                                               None
# 9                 US  20th Century Fox Film Corporation, Europacorp ...
#
#                        BB_Primary_Company    TMDB_ID  \
# 0                 Pixar Animation Studios  1076364.0
# 1                                    None        NaN
# 2                                    None   460658.0
# 3                                    None        NaN
# 4                                    None        NaN
# 5                                    None   301680.0
# 6                                    None        NaN
# 7                                    None        NaN
# 8                                    None        NaN
# 9  Twentieth Century Fox Film Corporation      262.0
#
#                                              BB_Cast
# 0                         Edward Asner, Bob Peterson
# 1                                               None
# 2  John Waters, Liam Gillick, Salvatore Viviano, ...
# 3                                               None
# 4                                               None
# 5                         Greg Finley, Howard Hughes
# 6                                               None
# 7                                               None
# 8                                               None
# 9  Robert De Niro, Jerry Lewis, Diahnne Abbott, S...
# Processo concluído.

# %%
# ==============================================================================
# BLOCO 6: LIMPEZA FINAL PRÉ-SPLINK 
# ==============================================================================

# Funções auxiliares de limpeza (mesmas do notebook 4)
def normalizar_string(texto):
    """Aplica limpeza segura: minúsculas, remove acentos e espaços extras."""
    if texto is None or pd.isna(texto):
        return None
    texto = str(texto).lower()
    texto = unidecode.unidecode(texto)
    return texto.strip()

def normalizar_lista_em_string(texto, separador=','):
    """Normaliza uma string que representa lista (ex.: elenco, diretores)."""
    if texto is None or pd.isna(texto):
        return None
    nomes = str(texto).split(separador)
    nomes_limpos = sorted([normalizar_string(n) for n in nomes if str(n).strip()])
    return separador.join(nomes_limpos) if nomes_limpos else None

print("\n" + "="*80)
print(" LIMPEZA FINAL PRÉ-SPLINK (conteúdo do passo 4, agora no passo 3)")
print("="*80)

try:
    # Entrada agora vem diretamente do BLOCO 5 (em memória), sem parquet intermediário
    df = df_dim.copy()

    print("\n--- Etapa de Limpeza Final Pré-Splink ---")
    df_limpo = df.copy()

    # 1) Normalização de campos textuais
    print("\n1. Normalizando campos de texto (títulos, país)...")
    df_limpo['BB_Title'] = df_limpo['BB_Title'].apply(normalizar_string)
    df_limpo['BB_Original_Title'] = df_limpo['BB_Original_Title'].apply(normalizar_string)
    df_limpo['BB_Primary_Country'] = df_limpo['BB_Primary_Country'].apply(normalizar_string)

    # 2) Padronização de listas (elenco e diretores)
    print("2. Padronizando e ordenando listas de elenco e diretores...")
    df_limpo['BB_Cast'] = df_limpo['BB_Cast'].apply(normalizar_lista_em_string)
    df_limpo['BB_Directors'] = df_limpo['BB_Directors'].apply(normalizar_lista_em_string)

    # 3) Ajuste de tipo (ano)
    print("3. Ajustando tipo de dado da coluna 'BB_Year'...")
    df_limpo['BB_Year'] = pd.to_numeric(df_limpo['BB_Year'], errors='coerce').astype('Int64')

    print("\nLimpeza concluída. Verificando uma amostra dos dados transformados:")
    colunas_preview = ['BB_Title', 'BB_Year', 'BB_Cast', 'BB_Directors']
    display(df_limpo[colunas_preview].head())

    # 4) Persistência FINAL (mesmo nome do notebook 4)
    df_limpo.to_parquet(ARQUIVO_DE_SAIDA, index=False)
    print(f"\n✔ Tabela dimensão final e limpa salva em: '{ARQUIVO_DE_SAIDA}'")

except Exception as e:
    print(f"\nOcorreu um erro durante o processo de limpeza: {e}")
# Out:
# ================================================================================
#  LIMPEZA FINAL PRÉ-SPLINK (conteúdo do passo 4, agora no passo 3)
# ================================================================================
#
# --- Etapa de Limpeza Final Pré-Splink ---
#
# 1. Normalizando campos de texto (títulos, país)...
# 2. Padronizando e ordenando listas de elenco e diretores...
# 3. Ajustando tipo de dado da coluna 'BB_Year'...
#
# Limpeza concluída. Verificando uma amostra dos dados transformados:
#                                             BB_Title  BB_Year  \
# 0                                        carl's date     2023
# 1                         live in the usa uriah heep     2003
# 2                       whatever happened to gelitin     2016
# 3  malaysia astro chinese international pageant 2019     2019
# 4                                  see you in denver     2006
#
#                                              BB_Cast       BB_Directors
# 0                          bob peterson,edward asner       bob peterson
# 1                                               None               None
# 2  agnes husslein-arco,ali janka,casey spooner,em...  angela christlieb
# 3                                               None               None
# 4                                               None           jan sikl
# ✔ Tabela dimensão final e limpa salva em: 'dados_catalogo\processed\tabela_dimensao_limpa_para_splink.parquet'
